# %%
import tensorflow as tf
import keras
from keras.layers import Activation, Dense, Dropout, Conv2D, Flatten, MaxPooling2D
from keras.models import Sequential
import librosa
import librosa.display
import numpy as np
import pandas as pd
import random

import warnings
warnings.filterwarnings('ignore')
# Out:
# Using TensorFlow backend.

# %%
data = pd.read_csv('Desktop/data/UrbanSound8K/metadata/UrbanSound8K.csv')
data.head(5)
# Out:
#       slice_file_name    fsID  start        end  salience  fold  classID  \
# 0    100032-3-0-0.wav  100032    0.0   0.317551         1     5        3
# 1  100263-2-0-117.wav  100263   58.5  62.500000         1     5        2
# 2  100263-2-0-121.wav  100263   60.5  64.500000         1     5        2
# 3  100263-2-0-126.wav  100263   63.0  67.000000         1     5        2
# 4  100263-2-0-137.wav  100263   68.5  72.500000         1     5        2
#
#               class
# 0          dog_bark
# 1  children_playing
# 2  children_playing
# 3  children_playing
# 4  children_playing

# %%
data.shape
# Out:
# (8732, 8)

# %%
# Get data over 3 seconds long
valid_data = data[['slice_file_name', 'fold' ,'classID', 'class']][ data['end']-data['start'] >= 3 ]
valid_data.shape
# Out:
# (7468, 4)

# %%
# Example of a Siren spectrogram
y, sr = librosa.load('Desktop/data/UrbanSound8K/audio/fold6/135160-8-0-0.wav', duration=2.97)
ps = librosa.feature.melspectrogram(y=y, sr=sr)
ps.shape
# Out:
# (128, 128)

# %%
valid_data['path'] = 'fold' + valid_data['fold'].astype('str') + '/' + valid_data['slice_file_name'].astype('str')

# %%
valid_data
# Out:
#          slice_file_name  fold  classID             class  \
# 1     100263-2-0-117.wav     5        2  children_playing
# 2     100263-2-0-121.wav     5        2  children_playing
# 3     100263-2-0-126.wav     5        2  children_playing
# 4     100263-2-0-137.wav     5        2  children_playing
# 5     100263-2-0-143.wav     5        2  children_playing
# 6     100263-2-0-161.wav     5        2  children_playing
# 7       100263-2-0-3.wav     5        2  children_playing
# 8      100263-2-0-36.wav     5        2  children_playing
# 14      100652-3-0-0.wav     2        3          dog_bark
# 15      100652-3-0-1.wav     2        3          dog_bark
# 16      100652-3-0-2.wav     2        3          dog_bark
# 17      100652-3-0-3.wav     2        3          dog_bark
# 18      100795-3-0-0.wav    10        3          dog_bark
# 19      100795-3-1-0.wav    10        3          dog_bark
# 20      100795-3-1-1.wav    10        3          dog_bark
# 21      100795-3-1-2.wav    10        3          dog_bark
# 22      100852-0-0-0.wav     5        0   air_conditioner
# 23      100852-0-0-1.wav     5        0   air_conditioner
# 24     100852-0-0-10.wav     5        0   air_conditioner
# 25     100852-0-0-11.wav     5        0   air_conditioner
# 26     100852-0-0-12.wav     5        0   air_conditioner
# 27     100852-0-0-13.wav     5        0   air_conditioner
# 28     100852-0-0-14.wav     5        0   air_conditioner
# 29     100852-0-0-15.wav     5        0   air_conditioner
# 30     100852-0-0-16.wav     5        0   air_conditioner
# 31     100852-0-0-17.wav     5        0   air_conditioner
# 32     100852-0-0-18.wav     5        0   air_conditioner
# 33     100852-0-0-19.wav     5        0   air_conditioner
# 34      100852-0-0-2.wav     5        0   air_conditioner
# 35     100852-0-0-20.wav     5        0   air_conditioner
# ...                  ...   ...      ...               ...
# 8699    99192-4-0-41.wav    10        4          drilling
# 8700    99192-4-0-43.wav    10        4          drilling
# 8701    99192-4-0-47.wav    10        4          drilling
# 8702    99192-4-0-48.wav    10        4          drilling
# 8703    99192-4-0-49.wav    10        4          drilling
# 8704    99192-4-0-52.wav    10        4          drilling
# 8705    99192-4-0-53.wav    10        4          drilling
# 8706    99192-4-0-54.wav    10        4          drilling
# 8707    99192-4-0-55.wav    10        4          drilling
# 8708     99192-4-0-7.wav    10        4          drilling
# 8709     99500-2-0-1.wav     9        2  children_playing
# 8710    99500-2-0-11.wav     9        2  children_playing
# 8711     99500-2-0-2.wav     9        2  children_playing
# 8712    99500-2-0-23.wav     9        2  children_playing
# 8713    99500-2-0-29.wav     9        2  children_playing
# 8714    99500-2-0-39.wav     9        2  children_playing
# 8715    99500-2-0-41.wav     9        2  children_playing
# 8716    99500-2-0-50.wav     9        2  children_playing
# 8717    99710-9-0-11.wav     6        9      street_music
# 8718    99710-9-0-12.wav     6        9      street_music
# 8719    99710-9-0-16.wav     6        9      street_music
# 8720     99710-9-0-2.wav     6        9      street_music
# 8721     99710-9-0-5.wav     6        9      street_music
# 8722     99710-9-0-6.wav     6        9      street_music
# 8723     99812-1-0-0.wav     7        1          car_horn
# 8724     99812-1-0-1.wav     7        1          car_horn
# 8725     99812-1-0-2.wav     7        1          car_horn
# 8726     99812-1-1-0.wav     7        1          car_horn
# 8727     99812-1-2-0.wav     7        1          car_horn
# 8729     99812-1-4-0.wav     7        1          car_horn
#
#                           path
# 1     fold5/100263-2-0-117.wav
# 2     fold5/100263-2-0-121.wav
# 3     fold5/100263-2-0-126.wav
# 4     fold5/100263-2-0-137.wav
# 5     fold5/100263-2-0-143.wav
# 6     fold5/100263-2-0-161.wav
# 7       fold5/100263-2-0-3.wav
# 8      fold5/100263-2-0-36.wav
# 14      fold2/100652-3-0-0.wav
# 15      fold2/100652-3-0-1.wav
# 16      fold2/100652-3-0-2.wav
# 17      fold2/100652-3-0-3.wav
# 18     fold10/100795-3-0-0.wav
# 19     fold10/100795-3-1-0.wav
# 20     fold10/100795-3-1-1.wav
# 21     fold10/100795-3-1-2.wav
# 22      fold5/100852-0-0-0.wav
# 23      fold5/100852-0-0-1.wav
# 24     fold5/100852-0-0-10.wav
# 25     fold5/100852-0-0-11.wav
# 26     fold5/100852-0-0-12.wav
# 27     fold5/100852-0-0-13.wav
# 28     fold5/100852-0-0-14.wav
# 29     fold5/100852-0-0-15.wav
# 30     fold5/100852-0-0-16.wav
# 31     fold5/100852-0-0-17.wav
# 32     fold5/100852-0-0-18.wav
# 33     fold5/100852-0-0-19.wav
# 34      fold5/100852-0-0-2.wav
# 35     fold5/100852-0-0-20.wav
# ...                        ...
# 8699   fold10/99192-4-0-41.wav
# 8700   fold10/99192-4-0-43.wav
# 8701   fold10/99192-4-0-47.wav
# 8702   fold10/99192-4-0-48.wav
# 8703   fold10/99192-4-0-49.wav
# 8704   fold10/99192-4-0-52.wav
# 8705   fold10/99192-4-0-53.wav
# 8706   fold10/99192-4-0-54.wav
# 8707   fold10/99192-4-0-55.wav
# 8708    fold10/99192-4-0-7.wav
# 8709     fold9/99500-2-0-1.wav
# 8710    fold9/99500-2-0-11.wav
# 8711     fold9/99500-2-0-2.wav
# 8712    fold9/99500-2-0-23.wav
# 8713    fold9/99500-2-0-29.wav
# 8714    fold9/99500-2-0-39.wav
# 8715    fold9/99500-2-0-41.wav
# 8716    fold9/99500-2-0-50.wav
# 8717    fold6/99710-9-0-11.wav
# 8718    fold6/99710-9-0-12.wav
# 8719    fold6/99710-9-0-16.wav
# 8720     fold6/99710-9-0-2.wav
# 8721     fold6/99710-9-0-5.wav
# 8722     fold6/99710-9-0-6.wav
# 8723     fold7/99812-1-0-0.wav
# 8724     fold7/99812-1-0-1.wav
# 8725     fold7/99812-1-0-2.wav
# 8726     fold7/99812-1-1-0.wav
# 8727     fold7/99812-1-2-0.wav
# 8729     fold7/99812-1-4-0.wav
#
# [7468 rows x 5 columns]

# %%
D = [] # Dataset

for row in valid_data.itertuples():
    y, sr = librosa.load('Desktop/data/UrbanSound8K/audio/' + row.path, duration=2.97)  
    ps = librosa.feature.melspectrogram(y=y, sr=sr)
    if ps.shape != (128, 128): continue
    D.append( (ps, row.classID) )

# %%
dataset = D
random.shuffle(dataset)

train = dataset[:7000]
test = dataset[7000:]

X_train, y_train = zip(*train)
X_test, y_test = zip(*test)

# Reshape for CNN input
X_train = np.array([x.reshape( (128, 128, 1) ) for x in X_train])
X_test = np.array([x.reshape( (128, 128, 1) ) for x in X_test])

# One-Hot encoding for classes
y_train = np.array(keras.utils.to_categorical(y_train, 10))
y_test = np.array(keras.utils.to_categorical(y_test, 10))

# %%
model = Sequential()
input_shape=(128, 128, 1)

model.add(Conv2D(24, (5, 5), strides=(1, 1), input_shape=input_shape))
model.add(MaxPooling2D((4, 2), strides=(4, 2)))
model.add(Activation('relu'))

model.add(Conv2D(48, (5, 5), padding="valid"))
model.add(MaxPooling2D((4, 2), strides=(4, 2)))
model.add(Activation('relu'))

model.add(Conv2D(48, (5, 5), padding="valid"))
model.add(Activation('relu'))

model.add(Flatten())
model.add(Dropout(rate=0.5))

model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(rate=0.5))

model.add(Dense(10))
model.add(Activation('softmax'))
# Out:
# WARNING:tensorflow:From C:\Users\abc\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\abc\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(
    x=X_train, 
    y=y_train,
    epochs=30,
    batch_size=128,
    validation_data= (X_test, y_test))
# Out:
# WARNING:tensorflow:From C:\Users\abc\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 7000 samples, validate on 467 samples
# Epoch 1/30
# 7000/7000 [==============================] - 130s 19ms/step - loss: 2.7504 - acc: 0.2180 - val_loss: 2.1268 - val_acc: 0.3084
# Epoch 2/30
# 7000/7000 [==============================] - 126s 18ms/step - loss: 2.0857 - acc: 0.2789 - val_loss: 1.9212 - val_acc: 0.2955
# Epoch 3/30
# 7000/7000 [==============================] - 125s 18ms/step - loss: 1.8476 - acc: 0.3451 - val_loss: 1.6898 - val_acc: 0.3919
# Epoch 4/30
# 7000/7000 [==============================] - 125s 18ms/step - loss: 1.7004 - acc: 0.3933 - val_loss: 1.5192 - val_acc: 0.4368
# Epoch 5/30
# 7000/7000 [==============================] - 126s 18ms/step - loss: 1.5869 - acc: 0.4396 - val_loss: 1.4182 - val_acc: 0.4690
# Epoch 6/30
# 7000/7000 [==============================] - 126s 18ms/step - loss: 1.4833 - acc: 0.4810 - val_loss: 1.3760 - val_acc: 0.5161
# Epoch 7/30
# 7000/7000 [==============================] - 125s 18ms/step - loss: 1.3996 - acc: 0.5169 - val_loss: 1.2829 - val_acc: 0.5953
# Epoch 8/30
# 7000/7000 [==============================] - 125s 18ms/step - loss: 1.3499 - acc: 0.5294 - val_loss: 1.2540 - val_acc: 0.5675
# Epoch 9/30
# 7000/7000 [==============================] - 125s 18ms/step - loss: 1.2642 - acc: 0.5653 - val_loss: 1.1428 - val_acc: 0.6253
# Epoch 10/30
# 7000/7000 [==============================] - 126s 18ms/step - loss: 1.1735 - acc: 0.5963 - val_loss: 1.1278 - val_acc: 0.6660
# Epoch 11/30
# 7000/7000 [==============================] - 124s 18ms/step - loss: 1.1421 - acc: 0.6111 - val_loss: 1.0986 - val_acc: 0.6467
# Epoch 12/30
# 7000/7000 [==============================] - 125s 18ms/step - loss: 1.1345 - acc: 0.6219 - val_loss: 1.1058 - val_acc: 0.6360
# Epoch 13/30
# 7000/7000 [==============================] - 123s 18ms/step - loss: 1.1198 - acc: 0.6313 - val_loss: 1.1086 - val_acc: 0.6681
# Epoch 14/30
# 7000/7000 [==============================] - 123s 18ms/step - loss: 1.0651 - acc: 0.6451 - val_loss: 0.9680 - val_acc: 0.7045
# Epoch 15/30
# 7000/7000 [==============================] - 124s 18ms/step - loss: 0.9706 - acc: 0.6783 - val_loss: 0.9593 - val_acc: 0.6724
# Epoch 16/30
# 7000/7000 [==============================] - 124s 18ms/step - loss: 0.9214 - acc: 0.7001 - val_loss: 0.8956 - val_acc: 0.7066
# Epoch 17/30
# 7000/7000 [==============================] - 124s 18ms/step - loss: 0.8829 - acc: 0.7177 - val_loss: 0.8973 - val_acc: 0.7323
# Epoch 18/30
# 7000/7000 [==============================] - 124s 18ms/step - loss: 0.8948 - acc: 0.7087 - val_loss: 1.0763 - val_acc: 0.6852
# Epoch 19/30
# 7000/7000 [==============================] - 124s 18ms/step - loss: 0.9255 - acc: 0.7051 - val_loss: 0.7727 - val_acc: 0.7666
# Epoch 20/30
# 7000/7000 [==============================] - 124s 18ms/step - loss: 0.8195 - acc: 0.7403 - val_loss: 0.9205 - val_acc: 0.7602
# Epoch 21/30
# 7000/7000 [==============================] - 123s 18ms/step - loss: 0.8016 - acc: 0.7399 - val_loss: 0.8169 - val_acc: 0.7602
# Epoch 22/30
# 7000/7000 [==============================] - 124s 18ms/step - loss: 0.7604 - acc: 0.7549 - val_loss: 0.8647 - val_acc: 0.7666
# Epoch 23/30
# 7000/7000 [==============================] - 124s 18ms/step - loss: 0.7221 - acc: 0.7693 - val_loss: 0.7116 - val_acc: 0.7859
# Epoch 24/30
# 7000/7000 [==============================] - 125s 18ms/step - loss: 0.6977 - acc: 0.7733 - val_loss: 0.7276 - val_acc: 0.8009
# Epoch 25/30
# 7000/7000 [==============================] - 124s 18ms/step - loss: 0.6844 - acc: 0.7807 - val_loss: 0.7515 - val_acc: 0.7752
# Epoch 26/30
# 7000/7000 [==============================] - 124s 18ms/step - loss: 0.7014 - acc: 0.7717 - val_loss: 0.7110 - val_acc: 0.7794
# Epoch 27/30
# 7000/7000 [==============================] - 124s 18ms/step - loss: 0.6925 - acc: 0.7754 - val_loss: 0.6972 - val_acc: 0.7880
# Epoch 28/30
# 7000/7000 [==============================] - 123s 18ms/step - loss: 0.6005 - acc: 0.8037 - val_loss: 0.7258 - val_acc: 0.7901
# Epoch 29/30
# 7000/7000 [==============================] - 123s 18ms/step - loss: 0.6199 - acc: 0.7977 - val_loss: 0.7386 - val_acc: 0.7880
# Epoch 30/30
# 7000/7000 [==============================] - 124s 18ms/step - loss: 0.6476 - acc: 0.7904 - val_loss: 0.6247 - val_acc: 0.8073

# %%
score = model.evaluate(
    x=X_test,
    y=y_test)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 467/467 [==============================] - 2s 5ms/step
# Test loss: 0.6246750721073763
# Test accuracy: 0.8072805150673272

# %%
model.predict(X_test).argmax(axis=1)
# Out:
# array([3, 5, 9, 5, 7, 8, 4, 8, 0, 2, 5, 5, 7, 0, 6, 5, 0, 7, 0, 7, 7, 9,
#        3, 4, 3, 7, 2, 2, 7, 4, 9, 5, 9, 9, 5, 2, 7, 9, 9, 5, 4, 2, 0, 8,
#        4, 9, 2, 9, 3, 7, 5, 7, 1, 2, 9, 2, 3, 5, 2, 4, 4, 4, 0, 8, 2, 2,
#        7, 2, 4, 1, 0, 5, 2, 8, 2, 2, 3, 8, 0, 9, 3, 0, 0, 2, 7, 2, 7, 7,
#        4, 8, 0, 0, 7, 4, 0, 5, 7, 5, 0, 9, 8, 0, 9, 9, 3, 5, 9, 3, 9, 1,
#        7, 7, 2, 9, 2, 0, 2, 7, 0, 5, 8, 6, 4, 8, 1, 7, 4, 9, 7, 4, 2, 0,
#        9, 7, 4, 5, 0, 3, 7, 3, 0, 0, 0, 7, 1, 3, 4, 7, 2, 9, 5, 7, 9, 7,
#        2, 4, 0, 7, 3, 9, 2, 9, 7, 9, 3, 2, 4, 0, 7, 0, 8, 9, 8, 5, 2, 0,
#        7, 7, 4, 9, 5, 4, 7, 1, 8, 7, 8, 5, 2, 5, 8, 9, 9, 8, 5, 5, 4, 4,
#        2, 5, 6, 0, 7, 9, 4, 0, 5, 2, 9, 7, 4, 7, 0, 5, 0, 8, 9, 2, 0, 2,
#        7, 8, 3, 9, 9, 2, 8, 2, 0, 1, 0, 2, 5, 5, 3, 5, 5, 2, 0, 7, 4, 8,
#        5, 5, 7, 5, 0, 7, 8, 0, 0, 9, 7, 8, 7, 0, 7, 7, 8, 3, 2, 5, 8, 5,
#        0, 2, 9, 5, 3, 7, 9, 5, 5, 2, 0, 0, 4, 3, 2, 2, 1, 0, 7, 2, 8, 8,
#        2, 9, 4, 5, 7, 0, 0, 0, 9, 4, 0, 0, 0, 9, 8, 2, 8, 9, 5, 7, 3, 5,
#        4, 2, 5, 7, 7, 8, 2, 9, 8, 3, 3, 8, 5, 8, 8, 0, 4, 9, 0, 0, 5, 5,
#        5, 5, 8, 0, 3, 2, 2, 3, 8, 0, 2, 0, 4, 9, 0, 7, 2, 9, 5, 7, 0, 0,
#        5, 2, 3, 2, 4, 9, 7, 9, 5, 3, 5, 8, 5, 2, 0, 4, 9, 4, 5, 7, 2, 0,
#        5, 9, 7, 8, 2, 8, 7, 5, 9, 2, 7, 2, 0, 2, 3, 9, 5, 4, 9, 0, 1, 5,
#        8, 0, 9, 4, 1, 2, 9, 5, 0, 8, 3, 5, 1, 8, 0, 5, 7, 7, 0, 7, 9, 2,
#        7, 1, 9, 3, 0, 0, 0, 5, 2, 0, 9, 2, 2, 8, 4, 2, 9, 8, 0, 4, 4, 4,
#        0, 2, 9, 5, 5, 9, 9, 0, 0, 8, 0, 7, 9, 0, 9, 0, 2, 9, 2, 2, 4, 8,
#        7, 5, 0, 0, 1], dtype=int64)

# %%
y_test.argmax(axis=1)
# Out:
# array([2, 5, 9, 5, 7, 8, 4, 8, 0, 8, 5, 5, 7, 8, 6, 5, 0, 1, 0, 7, 7, 9,
#        3, 4, 3, 7, 4, 2, 7, 9, 9, 5, 9, 9, 5, 2, 7, 9, 9, 5, 4, 2, 0, 8,
#        4, 9, 3, 9, 3, 7, 4, 7, 1, 3, 9, 9, 3, 5, 0, 4, 4, 4, 9, 8, 2, 8,
#        7, 9, 8, 1, 0, 7, 2, 8, 2, 0, 9, 8, 0, 9, 9, 0, 0, 2, 4, 2, 7, 7,
#        4, 8, 0, 5, 7, 4, 2, 5, 0, 5, 0, 9, 8, 0, 9, 9, 3, 5, 9, 2, 9, 1,
#        7, 7, 2, 9, 3, 2, 2, 7, 0, 5, 8, 6, 4, 8, 1, 7, 1, 9, 7, 4, 2, 0,
#        1, 7, 4, 5, 0, 3, 4, 3, 0, 0, 0, 7, 1, 3, 4, 7, 2, 9, 0, 7, 9, 7,
#        2, 4, 0, 7, 3, 9, 0, 9, 7, 9, 3, 9, 4, 9, 7, 0, 8, 9, 8, 5, 2, 0,
#        7, 7, 4, 9, 5, 3, 7, 1, 8, 4, 8, 5, 3, 5, 8, 9, 9, 8, 5, 5, 4, 4,
#        2, 5, 6, 5, 7, 9, 4, 0, 5, 2, 9, 9, 4, 7, 0, 5, 0, 5, 9, 2, 5, 9,
#        7, 8, 3, 9, 9, 2, 8, 2, 0, 5, 0, 2, 5, 2, 3, 5, 8, 3, 2, 7, 4, 8,
#        5, 5, 7, 0, 0, 7, 8, 0, 8, 9, 7, 8, 7, 9, 5, 4, 8, 3, 0, 5, 8, 5,
#        0, 2, 9, 5, 3, 8, 9, 5, 5, 2, 0, 5, 0, 3, 2, 9, 1, 0, 7, 2, 8, 8,
#        2, 9, 4, 0, 7, 0, 0, 0, 9, 4, 0, 0, 0, 9, 8, 2, 8, 9, 4, 7, 3, 5,
#        4, 2, 5, 7, 7, 4, 2, 9, 8, 3, 3, 8, 5, 8, 8, 9, 4, 9, 0, 4, 5, 5,
#        5, 5, 8, 0, 3, 2, 2, 3, 8, 0, 2, 9, 4, 9, 0, 7, 2, 9, 5, 8, 0, 0,
#        5, 2, 3, 8, 4, 9, 7, 9, 2, 3, 5, 8, 5, 3, 0, 4, 9, 4, 5, 7, 9, 0,
#        5, 9, 7, 8, 2, 8, 4, 5, 9, 2, 7, 2, 5, 3, 3, 9, 5, 3, 9, 0, 1, 5,
#        8, 0, 8, 4, 1, 0, 9, 5, 4, 8, 3, 5, 1, 5, 2, 5, 7, 7, 0, 7, 9, 6,
#        7, 1, 3, 3, 0, 0, 0, 5, 2, 7, 9, 3, 3, 8, 4, 2, 9, 8, 0, 4, 2, 4,
#        9, 2, 2, 5, 5, 1, 0, 0, 0, 8, 5, 4, 9, 0, 9, 0, 2, 9, 2, 9, 4, 8,
#        7, 5, 0, 2, 1], dtype=int64)
